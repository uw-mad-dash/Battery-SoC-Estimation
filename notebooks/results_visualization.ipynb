# %%
import os
import pandas as pd

df = pd.read_csv(os.path.join("..", "src", "inference", "results", "I_V_T_I_V_T.csv"))

# %%
import sys
if ".." not in sys.path:
    sys.path.insert(0, "..")
from src.inference.plot import plot_results
from src.inference.analysis import get_stats

LABEL_FEATURE = "SOC [%]"
PREDICTED_FEATURE = "SOC_PREDICTED [%]"

stats = get_stats(df, LABEL_FEATURE, PREDICTED_FEATURE)
fig = plot_results(df, stats, LABEL_FEATURE, PREDICTED_FEATURE)
# Out:
# 2023-01-19 17:56:13.710112: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
